# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow.compat.v1 as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
import os
visualMark1 = []
visualMark2 = []
visualMark3 = []
for imageName in os.listdir(r'1'):
    visualMark1.append(tf.keras.preprocessing.image.load_img('1/'+imageName))
    print("loaded asset", imageName)
for imageName in os.listdir(r'2'):
    visualMark1.append(tf.keras.preprocessing.image.load_img('2/'+imageName))
    print("loaded asset", imageName)
for imageName in os.listdir(r'3'):
    visualMark1.append(tf.keras.preprocessing.image.load_img('3/'+imageName))
    print("loaded asset", imageName)
# Out:
# loaded asset WIN_20230328_17_42_00_Pro.jpg
# loaded asset WIN_20230328_17_42_03_Pro.jpg
# loaded asset WIN_20230328_17_42_04_Pro.jpg
# loaded asset WIN_20230328_17_42_07_Pro.jpg
# loaded asset WIN_20230328_17_42_08_Pro.jpg
# loaded asset WIN_20230328_17_42_13_Pro.jpg
# loaded asset WIN_20230328_17_42_19_Pro (2).jpg
# loaded asset WIN_20230328_17_42_19_Pro.jpg
# loaded asset WIN_20230328_17_42_37_Pro.jpg
# loaded asset WIN_20230328_17_42_39_Pro.jpg
# loaded asset WIN_20230328_17_42_47_Pro.jpg
# loaded asset WIN_20230328_17_42_50_Pro.jpg
# loaded asset WIN_20230328_17_42_52_Pro.jpg
# loaded asset WIN_20230328_17_42_55_Pro.jpg
# loaded asset WIN_20230328_17_42_58_Pro.jpg
# loaded asset WIN_20230328_17_43_01_Pro.jpg
# loaded asset WIN_20230328_17_43_03_Pro.jpg
# loaded asset WIN_20230328_17_43_08_Pro.jpg
# loaded asset WIN_20230328_17_44_39_Pro.jpg
# loaded asset WIN_20230328_17_44_42_Pro.jpg
# loaded asset WIN_20230328_17_44_44_Pro.jpg
# loaded asset WIN_20230328_17_44_48_Pro.jpg
# loaded asset WIN_20230328_17_44_51_Pro.jpg
# loaded asset WIN_20230328_17_44_53_Pro.jpg
# loaded asset WIN_20230328_17_44_55_Pro.jpg
# loaded asset WIN_20230328_17_44_57_Pro.jpg
# loaded asset WIN_20230328_17_45_01_Pro.jpg
# loaded asset WIN_20230328_17_45_03_Pro.jpg
# loaded asset WIN_20230328_17_45_06_Pro.jpg
# loaded asset WIN_20230328_17_46_00_Pro.jpg
# loaded asset WIN_20230328_17_46_02_Pro.jpg
# loaded asset WIN_20230328_17_46_06_Pro.jpg
# loaded asset WIN_20230328_17_46_10_Pro.jpg
# loaded asset WIN_20230328_17_46_12_Pro.jpg
# loaded asset WIN_20230328_17_46_13_Pro.jpg
# loaded asset WIN_20230328_17_46_18_Pro.jpg
# loaded asset WIN_20230328_17_43_53_Pro.jpg
# loaded asset WIN_20230328_17_43_54_Pro.jpg
# loaded asset WIN_20230328_17_43_57_Pro.jpg
# loaded asset WIN_20230328_17_44_00_Pro.jpg
# loaded asset WIN_20230328_17_44_01_Pro.jpg
# loaded asset WIN_20230328_17_44_05_Pro.jpg
# loaded asset WIN_20230328_17_44_06_Pro.jpg
# loaded asset WIN_20230328_17_44_10_Pro.jpg
# loaded asset WIN_20230328_17_44_11_Pro.jpg
# loaded asset WIN_20230328_17_44_13_Pro (2).jpg
# loaded asset WIN_20230328_17_44_13_Pro.jpg
# loaded asset WIN_20230328_17_44_17_Pro.jpg
# loaded asset WIN_20230328_17_44_18_Pro.jpg
# loaded asset WIN_20230328_17_44_21_Pro.jpg
# loaded asset WIN_20230328_17_44_22_Pro.jpg
# loaded asset WIN_20230328_17_44_24_Pro.jpg
# loaded asset WIN_20230328_17_44_28_Pro.jpg
# loaded asset WIN_20230328_17_44_30_Pro.jpg

# %%
batch_size = 15
img_height = 720
img_width = 1280

train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_33/1297397227.py in <module>
#       3 img_width = 1280
#       4
# ----> 5 train_ds = tf.keras.utils.image_dataset_from_directory(
#       6   data_dir,
#       7   validation_split=0.2,
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/util/module_wrapper.py in _getattr(self, name)
#     234     """
#     235     try:
# --> 236       attr = getattr(self._tfmw_wrapped_module, name)
#     237     except AttributeError:
#     238     # Placeholder for Google-internal contrib error
#
# AttributeError: module 'keras.api._v1.keras.utils' has no attribute 'image_dataset_from_directory'

# %%
# process and cut the pictures
from PIL import Image
import os

path = '/home/mw/'
for i in range(1,4):
    for rawImage in os.listdir(path + str(i) + "/"):
        img = Image.open(path + str(i) + "/" + rawImage) # read image from file system
        img = img.rotate(180) # rotate it 180 degrees
        box = (400, 360, 760, 720) # the region that the signal sleeves will be seen
        img = img.crop(box) # cut the region down, into a 360 by 360 image
        img.show()
        img.save(path + str(i) + "/" + rawImage) # replace the original picture
# Out:
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF819C07050>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF819C4AB50>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF76B053090>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF819C4AB50>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF6C638BD50>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF819C4AB50>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF6C6C9E710>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF819C07050>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF819FE0D50>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF819C07050>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF6C64033D0>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF76B053090>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF6C64033D0>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF819C4AB50>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF6C64033D0>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF819C4AB50>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF8183557D0>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF819FE0D50>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF8183CBE50>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF6C6C9E710>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF8183CBE50>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF6C6C9E710>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF819C07050>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF6C6C9E710>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF819FE0D50>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF6C6C9E710>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF819FE0D50>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF6C64033D0>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF819FE0D50>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF819C07050>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF76B053090>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF8183CBE50>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF76B053090>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF8183CBE50>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF6C638BD50>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF8183CBE50>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF819C07050>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF8183CBE50>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF6C64033D0>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF76B053090>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF6C64033D0>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF819C4AB50>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF6C6C9E710>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF819C4AB50>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF819C07050>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF819C4AB50>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF8183557D0>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF6C64033D0>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF76B053090>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF8183CBE50>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF819FE0D50>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF819C07050>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF819FE0D50>
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7FF6C6C9E710>

# %%
import os
datas = []
labels = []
fpaths = []
for imageName in os.listdir(r'/home/mw/1/'):
    fpath = '/home/mw/1/'+imageName
    data = np.array(PIL.Image.open('/home/mw/1/'+imageName)) / 255.0
    label = 0
    fpaths.append(fpath)
    datas.append(data)
    labels.append(label)
for imageName in os.listdir(r'/home/mw/2/'):
    fpath = '/home/mw/2/'+imageName
    data = np.array(PIL.Image.open('/home/mw/2/'+imageName)) / 255.0
    label = 1
    fpaths.append(fpath)
    datas.append(data)
    labels.append(label)
for imageName in os.listdir(r'/home/mw/3/'):
    fpath = '/home/mw/3/'+imageName
    data = np.array(PIL.Image.open('/home/mw/3/'+imageName)) / 255.0
    label = 2
    fpaths.append(fpath)
    datas.append(data)
    labels.append(label)
    
datas = np.array(datas)
labels = np.array(labels)

num_classes = 3

# %%
tf.disable_eager_execution()
# 定义Placeholder，存放输入和标签
datas_placeholder = tf.placeholder(tf.float32, [None, 360, 360, 3])
labels_placeholder = tf.placeholder(
    tf.int32, 
    [None], 
    # name="output"
)

# 存放DropOut参数的容器，训练时为0.25，测试时为0
dropout_placeholdr = tf.placeholder(tf.float32)

# 定义卷积层, 20个卷积核, 卷积核大小为5，用Relu激活
conv0 = tf.layers.conv2d(datas_placeholder, 20, 5, activation=tf.nn.relu)
# 定义max-pooling层，pooling窗口为2x2，步长为2x2
pool0 = tf.layers.max_pooling2d(conv0, [2, 2], [2, 2])

# 定义卷积层, 40个卷积核, 卷积核大小为4，用Relu激活
conv1 = tf.layers.conv2d(pool0, 40, 4, activation=tf.nn.relu)
# 定义max-pooling层，pooling窗口为2x2，步长为2x2
pool1 = tf.layers.max_pooling2d(conv1, [2, 2], [2, 2])

# 将3维特征转换为1维向量
flatten = tf.layers.flatten(pool1)

# 全连接层，转换为长度为100的特征向量
fc = tf.layers.dense(flatten, 400, activation=tf.nn.relu)

# 加上DropOut，防止过拟合
dropout_fc = tf.layers.dropout(fc, dropout_placeholdr)

# 未激活的输出层
logits = tf.layers.dense(dropout_fc, num_classes)

predicted_labels = tf.arg_max(logits, 1)


# 利用交叉熵定义损失
losses = tf.nn.softmax_cross_entropy_with_logits(
    labels=tf.one_hot(labels_placeholder, num_classes),
    logits=logits
)
# 平均损失
mean_loss = tf.reduce_mean(losses)

# 定义优化器，指定要优化的损失函数
optimizer = tf.train.AdamOptimizer(learning_rate=1e-2).minimize(losses)

# %%
saver = tf.train.Saver()
train = True
model_path = "/home/mw/models/signal-sleeves-identifier.model"
tf.get_variable_scope().reuse_variables()
tf.reset_default_graph()
with tf.Session() as sess:
    if train:
        print("训练模式")
        # 如果是训练，初始化参数
        sess.run(tf.global_variables_initializer())
        # 定义输入和Label以填充容器，训练时dropout为0.25
        train_feed_dict = {
            datas_placeholder: datas,
            labels_placeholder: labels,
            dropout_placeholdr: 0.25
        }
        for step in range(2):
            _, mean_loss_val = sess.run([optimizer, mean_loss], feed_dict=train_feed_dict)

            print("step = {}\tmean loss = {}".format(step, mean_loss_val))
        '''tf.compat.v1.saved_model.simple_save( #保存模型
            sess, model_path, 
            inputs = {"myInput": datas_placeholder},
            outputs = {"myOutput" :labels_placeholder}
        )'''
        saver.save(sess, model_path)
        print("训练结束，保存模型到{}".format(model_path))
    
    
    else:
        print("测试模式")
        # 如果是测试，载入参数
        saver.restore(sess, model_path)
        print("从{}载入模型".format(model_path))
        # label和名称的对照关系
        label_name_dict = {
            0: "标识1",
            1: "标识2",
            2: "标识3"
        }
        # 定义输入和Label以填充容器，测试时dropout为0
        test_feed_dict = {
            datas_placeholder: datas,
            labels_placeholder: labels,
            dropout_placeholdr: 0
        }
        predicted_labels_val = sess.run(predicted_labels, feed_dict=test_feed_dict)
        # 真实label与模型预测label
        for fpath, real_label, predicted_label in zip(fpaths, labels, predicted_labels_val):
            # 将label id转换为label名
            real_label_name = label_name_dict[real_label]
            predicted_label_name = label_name_dict[predicted_label]
            print("{}\t{} => {}".format(fpath, real_label_name, predicted_label_name))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_35/1263148125.py in <module>
# ----> 1 saver = tf.train.Saver()
#       2 train = True
#       3 model_path = "/home/mw/models/signal-sleeves-identifier.model"
#       4 tf.get_variable_scope().reuse_variables()
#       5 tf.reset_default_graph()
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/training/saver.py in __init__(self, var_list, reshape, sharded, max_to_keep, keep_checkpoint_every_n_hours, name, restore_sequentially, saver_def, builder, defer_build, allow_empty, write_version, pad_step_number, save_relative_paths, filename)
#     834           time.time() + self._keep_checkpoint_every_n_hours * 3600)
#     835     elif not defer_build:
# --> 836       self.build()
#     837     if self.saver_def:
#     838       self._check_saver_def()
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/training/saver.py in build(self)
#     846     if context.executing_eagerly():
#     847       raise RuntimeError("Use save/restore instead of build in eager mode.")
# --> 848     self._build(self._filename, build_save=True, build_restore=True)
#     849
#     850   def _build_eager(self, checkpoint_path, build_save, build_restore):
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/training/saver.py in _build(self, checkpoint_path, build_save, build_restore)
#     884           filename=checkpoint_path,
#     885           build_save=build_save,
# --> 886           build_restore=build_restore)
#     887     elif self.saver_def and self._name:
#     888       # Since self._name is used as a name_scope by builder(), we are
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/training/saver.py in _build_internal(self, names_to_saveables, reshape, sharded, max_to_keep, keep_checkpoint_every_n_hours, name, restore_sequentially, filename, build_save, build_restore)
#     488
#     489     saveables = saveable_object_util.validate_and_slice_inputs(
# --> 490         names_to_saveables)
#     491     if max_to_keep is None:
#     492       max_to_keep = 0
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/training/saving/saveable_object_util.py in validate_and_slice_inputs(names_to_saveables)
#     353   """
#     354   if not isinstance(names_to_saveables, dict):
# --> 355     names_to_saveables = op_list_to_dict(names_to_saveables)
#     356
#     357   saveables = []
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/training/saving/saveable_object_util.py in op_list_to_dict(op_list, convert_variable_to_tensor)
#     310         if name in names_to_saveables:
#     311           raise ValueError("At least two variables have the same name: %s" %
# --> 312                            name)
#     313         names_to_saveables[name] = var
#     314
#
# ValueError: At least two variables have the same name: beta1_power

# %%
import tensorflow as tf
from tensorflow.python.platform import gfile

'''# first, convert the model into pbtxt file
with gfile.FastGFile(model_path + "/saved_model.pb") as f:
  graph_def = tf.compat.v1.GraphDef()
  graph_def.ParseFromString(f.read())
  tf.import_graph_def(graph_def, name='')
  tf.train.write_graph(graph_def, "./", "signal_sleeves.pbtxt", as_text=True)
'''

# Convert the model
converter = tf.compat.v1.lite.TFLiteConverter.from_saved_model("/home/mw/models/") # path to the SavedModel directory

tflite_model = converter.convert()

# Save the model.
with open('model.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/lite/python/convert_saved_model.py:63: load (from tensorflow.python.saved_model.loader_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.loader.load or tf.compat.v1.saved_model.load. There will be a new function for importing SavedModels in Tensorflow 2.0.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_35/623159061.py in <module>
#      11
#      12 # Convert the model
# ---> 13 converter = tf.compat.v1.lite.TFLiteConverter.from_saved_model("/home/mw/models/") # path to the SavedModel directory
#      14
#      15 tflite_model = converter.convert()
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/lite/python/lite.py in from_saved_model(cls, saved_model_dir, input_arrays, input_shapes, output_arrays, tag_set, signature_key)
#    2265
#    2266     saved_model_converter = TFLiteSavedModelConverter(saved_model_dir, tag_set,
# -> 2267                                                       [signature_key])
#    2268     if saved_model_converter.saved_model_dir:
#    2269       return saved_model_converter
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/lite/python/lite.py in __init__(self, saved_model_dir, saved_model_tags, saved_model_exported_names, experimental_debug_info_func)
#    1742
#    1743     result = _freeze_saved_model(self.saved_model_dir, None, None, None,
# -> 1744                                  self._saved_model_tags, signature_key)
#    1745     self._graph_def = result[0]
#    1746     self._input_tensors = result[1]
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/lite/python/convert_phase.py in wrapper(*args, **kwargs)
#     216       except Exception as error:
#     217         report_error_message(str(error))
# --> 218         raise error from None  # Re-throws the exception.
#     219
#     220     return wrapper
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/lite/python/convert_phase.py in wrapper(*args, **kwargs)
#     206     def wrapper(*args, **kwargs):
#     207       try:
# --> 208         return func(*args, **kwargs)
#     209       except ConverterError as converter_error:
#     210         if converter_error.errors:
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/lite/python/convert_saved_model.py in freeze_saved_model(saved_model_dir, input_arrays, input_shapes, output_arrays, tag_set, signature_key)
#     189   """
#     190   # Read SignatureDef.
# --> 191   meta_graph = get_meta_graph_def(saved_model_dir, tag_set)
#     192   signature_def = get_signature_def(meta_graph, signature_key)
#     193   inputs, outputs = get_inputs_outputs(signature_def)
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/lite/python/convert_saved_model.py in get_meta_graph_def(saved_model_dir, tag_set)
#      61   """
#      62   with session.Session(graph=ops.Graph()) as sess:
# ---> 63     return loader.load(sess, tag_set, saved_model_dir)
#      64
#      65
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     344               'in a future version' if date is None else ('after %s' % date),
#     345               instructions)
# --> 346       return func(*args, **kwargs)
#     347
#     348     doc_controls.set_deprecated(new_func)
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/saved_model/loader_impl.py in load(sess, tags, export_dir, import_scope, **saver_kwargs)
#     343   @end_compatibility
#     344   """
# --> 345   loader = SavedModelLoader(export_dir)
#     346   return loader.load(sess, tags, import_scope, **saver_kwargs)
#     347
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/saved_model/loader_impl.py in __init__(self, export_dir)
#     359     self._export_dir = export_dir
#     360     self._variables_path = saved_model_utils.get_variables_path(export_dir)
# --> 361     self._saved_model = parse_saved_model(export_dir)
#     362
#     363   @property
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/saved_model/loader_impl.py in parse_saved_model(export_dir)
#     119         "SavedModel file does not exist at: %s%s{%s|%s}" %
#     120         (export_dir, os.path.sep, constants.SAVED_MODEL_FILENAME_PBTXT,
# --> 121          constants.SAVED_MODEL_FILENAME_PB))
#     122
#     123
#
# OSError: SavedModel file does not exist at: /home/mw/models//{saved_model.pbtxt|saved_model.pb}

# %%
os.system("tflite_convert --saved_model_dir=./signal-sleeves-identifier.pb.data-00000-of-00001 --output_file=./signal_sleeves.tflite")
# Out:
# Traceback (most recent call last):
#   File "/opt/conda/bin/tflite_convert", line 8, in <module>
#     sys.exit(main())
#   File "/opt/conda/lib/python3.7/site-packages/tensorflow/lite/python/tflite_convert.py", line 697, in main
#     app.run(main=run_main, argv=sys.argv[:1])
#   File "/opt/conda/lib/python3.7/site-packages/absl/app.py", line 312, in run
#     _run_main(main, args)
#   File "/opt/conda/lib/python3.7/site-packages/absl/app.py", line 258, in _run_main
#     sys.exit(main(argv))
#   File "/opt/conda/lib/python3.7/site-packages/tensorflow/lite/python/tflite_convert.py", line 680, in run_main
#     _convert_tf2_model(tflite_flags)
#   File "/opt/conda/lib/python3.7/site-packages/tensorflow/lite/python/tflite_convert.py", line 284, in _convert_tf2_model
#     tags=_parse_set(flags.saved_model_tag_set))
#   File "/opt/conda/lib/python3.7/site-packages/tensorflow/lite/python/lite.py", line 1348, in from_saved_model
#     saved_model = _load(saved_model_dir, tags)
#   File "/opt/conda/lib/python3.7/site-packages/tensorflow/python/saved_model/load.py", line 864, in load
#     result = load_internal(export_dir, tags, options)["root"]
#   File "/opt/conda/lib/python3.7/site-packages/tensorflow/python/saved_model/load.py", line 878, in load_internal
#     loader_impl.parse_saved_model_with_debug_info(export_dir))
#   File "/opt/conda/lib/python3.7/site-packages/tensorflow/python/saved_model/loader_impl.py", line 60, in parse_saved_model_with_debug_info
#     saved_model = _parse_saved_model(export_dir)
#   File "/opt/conda/lib/python3.7/site-packages/tensorflow/python/saved_model/loader_impl.py", line 121, in parse_saved_model
#     constants.SAVED_MODEL_FILENAME_PB))
# OSError: SavedModel file does not exist at: ./signal-sleeves-identifier.pb.data-00000-of-00001/{saved_model.pbtxt|saved_model.pb}
# 256

# %%
# 以下为格式转换
import tensorflow as tf
# 首先，获取节点名称
saver = tf.compat.v1.train.import_meta_graph(model_path + '.meta', clear_devices=True)
graph = tf.compat.v1.get_default_graph()
input_graph_def = graph.as_graph_def()
with tf.compat.v1.Session() as sess:
    for n in tf.compat.v1.get_default_graph().as_graph_def().node:
        if "Placeholder" in n.name:
            print(n.name)

# 冻结为固定参数模型
saver = tf.compat.v1.train.import_meta_graph(model_path + ".meta")
graph = tf.compat.v1.get_default_graph()
input_graph_def = graph.as_graph_def()
with tf.compat.v1.Session() as sess:
    saver.restore(sess, model_path)
    output_graph_def = tf.compat.v1.graph_util.convert_variables_to_constants(
        sess = sess,
        input_graph_def = input_graph_def,
        output_node_names = ["Placeholder_2"]
    )
    with tf.compat.v1.gfile.GFile("/home/mw/frozen.pb", "wb") as f:
        f.write(output_graph_def.SerializeToString())
# Out:
# Placeholder
# Placeholder_1
# Placeholder_2
# Placeholder_3
# Placeholder_1_1
# Placeholder_2_1
# Placeholder_4
# Placeholder_1_2
# Placeholder_2_2
# Placeholder_5
# Placeholder_1_3
# Placeholder_2_3
# Placeholder_6
# Placeholder_1_4
# Placeholder_2_4
# Placeholder_7
# Placeholder_1_5
# Placeholder_2_5
# Placeholder_8
# Placeholder_1_6
# Placeholder_2_6
# Placeholder_9
# Placeholder_1_7
# Placeholder_2_7
# Placeholder_10
# Placeholder_1_8
# Placeholder_2_8
# Placeholder_11
# Placeholder_1_9
# Placeholder_2_9
# Placeholder_12
# Placeholder_1_10
# Placeholder_2_10
# Placeholder_13
# Placeholder_1_11
# Placeholder_2_11
# Placeholder_14
# Placeholder_1_12
# Placeholder_2_12
# Placeholder_15
# Placeholder_1_13
# Placeholder_2_13
# Placeholder_16
# Placeholder_1_14
# Placeholder_2_14
# Placeholder_17
# Placeholder_1_15
# Placeholder_2_15
# Placeholder_18
# Placeholder_1_16
# Placeholder_2_16
# Placeholder_19
# Placeholder_1_17
# Placeholder_2_17
# Placeholder_20
# Placeholder_1_18
# Placeholder_2_18
# Placeholder_21
# Placeholder_1_19
# Placeholder_2_19
# Placeholder_22
# Placeholder_1_20
# Placeholder_2_20
# Placeholder_23
# Placeholder_1_21
# Placeholder_2_21
# Placeholder_24
# Placeholder_1_22
# Placeholder_2_22
# Placeholder_25
# Placeholder_1_23
# Placeholder_2_23
# Placeholder_26
# Placeholder_1_24
# Placeholder_2_24
# Placeholder_27
# Placeholder_1_25
# Placeholder_2_25
# INFO:tensorflow:Restoring parameters from /home/mw/models/signal-sleeves-identifier.model
